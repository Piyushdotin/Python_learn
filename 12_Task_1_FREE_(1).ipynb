# %% [markdown]
# <a href="https://colab.research.google.com/github/Piyushdotin/Python_learn/blob/main/12_Task_1_FREE_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
# Write your code here
print("Data","Science","Mentorship","Program",sep= "-", end=('-started'))
print("-By","CampusX", sep="-")
# Out:
# Data-Science-Mentorship-Program-started-By-CampusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
# Write your code here
celsius=int(input('Enter the temp in celsius'))
faren = celsius * 1.8 + 32
print(faren)
# Out:
# Enter the temp in celsius100
# 212.0

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
# Write your code here
a=int(input('Enter the first number'))
b=int(input('Enter the second number'))
temp=a
a=b
b=temp
print(a,b)
# Out:
# Enter the first number1
# Enter the second number2
# 2 1

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
# Write your code here
x1=int(input('Enter the first x coordinate'))
y1=int(input('Enter the first y coordinate'))
x2=int(input('Enter the second x coordinate'))
y2=int(input('Enter the second y coordinate'))
distance = ((x2-x1)**2 + (y2-y1)**2)**0.5
print(distance)
# Out:
# Enter the first x coordinate10
# Enter the first y coordinate12
# Enter the second x coordinate1
# Enter the second y coordinate23
# 14.212670403551895

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
# Write your code here
p=int(input('Enter principle amount'))
r=int(input('rate'))
t=int(input('time'))

si=p*r*t/100
print(si)
# Out:
# Enter principle amount100
# rate10
# time5
# 50.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
# Write your code here
heads=int(input('Number of heads'))
legs=int(input('Number of legs'))

dogs= (legs - 2 * heads) // 2
chicken = heads-dogs

print("dogs=",dogs)
print("chicken=",chicken)
# Out:
# Number of heads2
# Number of legs6
# dogs= 1
# chicken= 1

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
# Write your code here
n=int(input('Value of n'))

formula = (n*(n+1) * (2*n + 1))//6

print(formula)
# Out:
# Value of n5
# 55

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
# Write your code here

First_Term = int(input('Enter 1st term'))
Second_Term = int(input('Enter 2nd term'))
Nth_Term = int(input('Value of n'))

d = Second_Term - First_Term

formula = First_Term + (Nth_Term - 1) * d

print(formula)
# Out:
# Enter 1st term2
# Enter 2nd term4
# Value of n10
# 20

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
# Write your code here

Nr1 = int(input('enter 1st Nr'))
Dr1 = int(input('enter 1st Dr'))

Nr2 = int(input('enter 2nd Nr'))
Dr2 = int(input('enter 2nd Dr'))

formula = (Nr1//Dr1) + (Nr2//Dr2)

print(formula)
# Out:
# enter 1st Nr10
# enter 1st Dr5
# enter 2nd Nr10
# enter 2nd Dr5
# 4

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# Write your code here
h=int(input('Enter height'))
l=int(input('Enter lenght'))
b=int(input('Enter breadth'))

gh=float(input('height of glass'))
gr=float(input('radius of glass'))

volume_of_milk_tank = h*l*b
volume_of_milk_glass = 3.14 * gr*gr * gh

Numbers_of_glass=volume_of_milk_tank//volume_of_milk_glass
print(Numbers_of_glass)
# Out:
# Enter height20
# Enter lenght20
# Enter breadth20
# height of glass3
# radius of glass1
# 849.0
